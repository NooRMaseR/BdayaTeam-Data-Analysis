# %% [markdown]
# <div dir='rtl'>
#     <ol>
#         <li>عمل <code>pie</code> لمعرفة نسبة استخدام طرق الدفع</li>
#         <li>عمل <code>pie</code> لمعرفة نسبة الراحلون من حيث نوع العقد الشهرى او السنوى</li>
#         <li>ما هى اسباب ترك العملاء للخدمه؟</li>
#     </ol>
# <div>

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    "Telco-Customer-Churn.csv",
    true_values=['Yes'],
    false_values=['No'],
    dtype={
        "SeniorCitizen": np.bool_
    }
)
df['TotalCharges'] = np.where(df['TotalCharges'] == ' ', 0, df['TotalCharges'])
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female          False     True       False       1
# 1  5575-GNVDE    Male          False    False       False      34
# 2  3668-QPYBK    Male          False    False       False       2
# 3  7795-CFOCW    Male          False    False       False      45
# 4  9237-HQITU  Female          False    False       False       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0         False  No phone service             DSL             No  ...
# 1          True                No             DSL            Yes  ...
# 2          True                No             DSL            Yes  ...
# 3         False  No phone service             DSL            Yes  ...
# 4          True                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0             True           Electronic check          29.85         29.85
# 1            False               Mailed check          56.95        1889.5
# 2             True               Mailed check          53.85        108.15
# 3            False  Bank transfer (automatic)          42.30       1840.75
# 4             True           Electronic check          70.70        151.65
#
#    Churn
# 0  False
# 1  False
# 2   True
# 3  False
# 4   True
#
# [5 rows x 21 columns]

# %%
payments = df['PaymentMethod'].value_counts()

plt.pie(
    payments.values,
    autopct="%1.2f%%",
    labels=payments.index
)
plt.show()
payments
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
dummy_df = pd.get_dummies(df, columns=['gender', "MultipleLines" ,"InternetService" ,"OnlineSecurity" ,"OnlineBackup" ,"DeviceProtection" ,"TechSupport" ,"StreamingTV" ,"StreamingMovies" , "Contract", 'PaymentMethod'])

# %%
X = dummy_df.drop(columns=['Churn', 'customerID'])
Y = dummy_df['Churn']

# %%
model = RandomForestClassifier()
model.fit(X,Y)
# Out:
# RandomForestClassifier()

# %%
importance = pd.DataFrame(
    {
        "Columns": X.columns,
        "Importance": np.round(model.feature_importances_ * 100, 2)
    }
).sort_values("Importance", ascending=False)
importance
# Out:
#                                     Columns  Importance
# 7                              TotalCharges       17.15
# 6                            MonthlyCharges       14.88
# 3                                    tenure       14.48
# 34                  Contract_Month-to-month        5.12
# 16                        OnlineSecurity_No        2.93
# 39           PaymentMethod_Electronic check        2.89
# 14              InternetService_Fiber optic        2.63
# 25                           TechSupport_No        2.63
# 5                          PaperlessBilling        2.56
# 1                                   Partner        2.24
# 0                             SeniorCitizen        2.08
# 36                        Contract_Two year        1.96
# 2                                Dependents        1.91
# 19                          OnlineBackup_No        1.91
# 9                               gender_Male        1.81
# 8                             gender_Female        1.77
# 22                      DeviceProtection_No        1.43
# 35                        Contract_One year        1.34
# 10                         MultipleLines_No        1.31
# 12                        MultipleLines_Yes        1.28
# 27                          TechSupport_Yes        1.23
# 38    PaymentMethod_Credit card (automatic)        1.21
# 37  PaymentMethod_Bank transfer (automatic)        1.19
# 40               PaymentMethod_Mailed check        1.13
# 24                     DeviceProtection_Yes        1.13
# 21                         OnlineBackup_Yes        1.12
# 18                       OnlineSecurity_Yes        1.10
# 28                           StreamingTV_No        1.09
# 31                       StreamingMovies_No        1.08
# 33                      StreamingMovies_Yes        1.07
# 30                          StreamingTV_Yes        1.07
# 13                      InternetService_DSL        1.00
# 4                              PhoneService        0.38
# 11           MultipleLines_No phone service        0.34
# 15                       InternetService_No        0.34
# 20         OnlineBackup_No internet service        0.31
# 17       OnlineSecurity_No internet service        0.29
# 29          StreamingTV_No internet service        0.22
# 32      StreamingMovies_No internet service        0.16
# 26          TechSupport_No internet service        0.15
# 23     DeviceProtection_No internet service        0.07

# %%
pd.pivot_table(
    data=df, 
    index='Contract', 
    columns='Churn', 
    values='customerID', 
    aggfunc='count'
)
# Out:
# Churn           False  True
# Contract
# Month-to-month   2220   1655
# One year         1307    166
# Two year         1647     48

# %%
import pickle

with open("model.pkl", 'wb') as f:
    pickle.dump(model, f)
